# %%
import pandas as pd

df = pd.read_csv('C:/Users/ajjadhav/Downloads/WECs_DataSet/Adelaide_Data.csv',header=None)

# %%
newdf = df.iloc[:,[0,16,32]]

# %%
newdf.columns =['X','Y','P']

# %%
newdf.head()
# Out:
#           X         Y           P
# 0  316.5855  180.9224  78738.9831
# 1  530.3136  510.7784  97185.2149
# 2   27.3967  102.5081  76929.3586
# 3  346.1526  441.9194  95372.9014
# 4  317.9144   94.6465  74526.6183

# %%
import matplotlib.pyplot as plt

plt.scatter(newdf['X'], newdf['Y'],\
            c=newdf['P'], cmap=plt.cm.autumn)
